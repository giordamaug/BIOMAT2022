# %% [markdown]
# <a href="https://colab.research.google.com/github/giordamaug/BIOMAT2022/blob/main/BIOMATA2022 workbench.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# # Cloning BIOMAT2022 repository

# %%
# !git clone http://github.com/giordamaug/BIOMAT2022

# %% [markdown]
#  # Run the script
#
# Usage: `nodeclassification.py`
#
# `[-h]`  : print this help
#
# `[-a <attributes> [<attributes> ...]]` : attribute sets to consider (`BIO`,`GTEX`,`EMBED`)
#
# `[-d <datadir>]` : directory of input files
#
# `[-l <labelname>]` : type of label to comsider
#
# use: `label_CS_ACH_most_freq` for Ilaria's labeling
#
# `[-n <network>]` : network to consider for embedding (`PPI`,`MET`,`MET+PPI`) - works if `-a ... EMBED`
#
# `[-Z <normalize>]` : gene attribute normalization (`None`,`zscore`,`minmax`)
#
# `[-e <embedder>]` : embedder method - works if `-a ... EMBED`
#
# `[-m <method>]` : classifier method
#
# `[-L]` : load precomputed embedding - works if `-a ... EMBED`
#
# `[-S]` : save embedding - works if `-a ... EMBED`

# %%
# !pip install -q karateclub
# !pip install -q lightgbm
# !python nodeclassification.py -d datasets \
                              -Z zscore \
                              -e Node2Vec \
                              -a BIO GTEX EMBED \
                              -e Node2Vec \
                              -n PPI \
                              -L \
                              -m LGBM \
                              -l label_CS_ACH_most_freq
# Out:
# usage: nodeclassification.py [-h] [-a <attributes> [<attributes> ...]]
#                              [-d <datadir>] [-l <labelname>]
#                              [-E <essential-groups> [<essential-groups> ...]]
#                              [-N <not-essential-groups> [<not-essential-groups> ...]]
#                              [-n <network>] [-Z <normalize>] [-e <embedder>]
#                              [-m <method>] [-V] [-S] [-L] [-X]
#
# BIOMAT 2022 Workbench
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a <attributes> [<attributes> ...], --attributes <attributes> [<attributes> ...]
#                         attributes to consider (default BIO GTEX EMBED, values
#                         BIO,GTEX,EMBED)
#   -d <datadir>, --datadir <datadir>
#                         data directory (default datasets)
#   -l <labelname>, --labelname <labelname>
#                         label name (default label_CS_ACH_most_freq)
#   -E <essential-groups> [<essential-groups> ...], --essentials <essential-groups> [<essential-groups> ...]
#                         CS groups of essential genes (default: CS0, range:
#                         [CS0,...,CS9]
#   -N <not-essential-groups> [<not-essential-groups> ...], --nonessenzials <not-essential-groups> [<not-essential-groups> ...]
#                         CS groups of non essential genes (default: CS6 CS7 CS8
#                         CS9], range: [CS0,...,CS9]
#   -n <network>, --network <network>
#                         network (default: PPI, choice: PPI|MET|MET+PPI)
#   -Z <normalize>, --normalize <normalize>
#                         normalize mode (default: None, choice:
#                         None|zscore|minmax)
#   -e <embedder>, --embedder <embedder>
#                         embedder name (default: RandNE, choice:
#                         RandNE|Node2Vec|GLEE|DeepWalk|HOPE)
#   -m <method>, --method <method>
#                         classifier name (default: RF, choice:
#                         RF|SVM|XGB|LGBM|MLP)
#   -V, --verbose
#   -S, --save-embedding
#   -L, --load-embedding
#   -X, --display
